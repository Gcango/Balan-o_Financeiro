# %% [markdown]
# <a href="https://colab.research.google.com/github/Gcango/Balan-o_Financeiro/blob/main/Balan_Finan_panguiLda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Balanço Financeiro,
# O objectivo deste exercicio é ajudar a Pangui, Lda na auditoria dos seus dados financeiro, com base nas suas receitas e despesas. Como objectivo nesta auditoria, procurou-se responder as seguintes questões:
# a) - Qual foi o Lucro de cada Mês da Empresa Pangui Lda?
# b) Qual foi o Lucro após imposto para cada mês com uma taxa de imposto de 30%?
# c) Qual foi a margem de lucro de cada mês?
# d)Qual foi o lucro após o imposto dividido pela receita
# e)Quais seriam considerados os bons meses, tendo em conta que o lucro após o imposto foi maior que a média do ano?
# f)Quais seriam considerados os péssimos meses, tendo em conta que que o lucro após o imposto foi menor que a média do ano?
# g) Qual seria considerado o melhor mês, tendo em conta que o lucro após o imposto foi o máximo para o ano?
# h) Qual seria o pior mês, tendo em conta que o lucro após o imposto foi o minimo para o ano?
#
# Assim sendo, foi feita a devida analise produzindo um conjunto de insight que podem ser uma importantes para a tomada de decisão na Pangui, Lda.

# %%
#Carregando os valores das receitas e despesas mensais
receitas = [14574.49, 7606.46, 8611.41, 9175.41, 8058.65, 8105.44, 11496.28, 9766.09, 10305.32, 14379.96, 10713.97, 15433.50]
despesas = [12051.82, 5695.07, 12319.20, 12089.72, 8658.57, 840.20, 3285.73, 5821.12, 6976.93, 16618.61, 10054.37, 3803.96]

# %%
#Encontrando o Lucro de cada mês (a)

# %%
lucro = list([])

for i in range (0, len(receitas)):
  lucro.append(receitas[i] - despesas[i])

lucro_final = pd.DataFrame(lucro, index=['Jan','Fev', 'Mar','Abr','Mai','Jun','Jul','Agos','Set','Out','Nov','Dez'])
lucro_final.reset_index()
# Out:
#    index         0
# 0    Jan   2522.67
# 1    Fev   1911.39
# 2    Mar  -3707.79
# 3    Abr  -2914.31
# 4    Mai   -599.92
# 5    Jun   7265.24
# 6    Jul   8210.55
# 7   Agos   3944.97
# 8    Set   3328.39
# 9    Out  -2238.65
# 10   Nov    659.60
# 11   Dez  11629.54

# %%
#Encontrado o Lucro após o imposto de 30% (b)

# %%
imposto_de_30 = [round (i * 0.3, 2) for i in lucro]
imposto_de_30_final = pd.DataFrame(imposto_de_30, index=['Jan','Fev', 'Mar','Abr','Mai','Jun','Jul','Agos','Set','Out','Nov','Dez'])
imposto_de_30_final
# Out:
#             0
# Jan    756.80
# Fev    573.42
# Mar  -1112.34
# Abr   -874.29
# Mai   -179.98
# Jun   2179.57
# Jul   2463.17
# Agos  1183.49
# Set    998.52
# Out   -671.60
# Nov    197.88
# Dez   3488.86

# %%
#Margem de Lucro para cada mês (c)

# %%
lucro_de_30 = list([])

for i in range(0, len(lucro)):
  lucro_de_30.append(lucro[i] - imposto_de_30[i])
lucro_de_30_meses = pd.DataFrame(lucro_de_30, index=['Jan','Fev', 'Mar','Abr','Mai','Jun','Jul','Agos','Set','Out','Nov','Dez'])
lucro_de_30_meses
# Out:
#             0
# Jan   1765.87
# Fev   1337.97
# Mar  -2595.45
# Abr  -2040.02
# Mai   -419.94
# Jun   5085.67
# Jul   5747.38
# Agos  2761.48
# Set   2329.87
# Out  -1567.05
# Nov    461.72
# Dez   8140.68

# %%
#Margem de Lucro para cada mês depois de 30% (d)

# %%
margem_lucro_dep_30 = list([])

for i in range(0, len(lucro)):
  margem_lucro_dep_30.append(lucro_de_30[i]/receitas[i])
margem_lucro_dep_30 = [round ((i * 100), 2) for i in margem_lucro_dep_30]
margem_lucro_dep_30_final = pd.DataFrame(margem_lucro_dep_30, index=['Jan','Fev', 'Mar','Abr','Mai','Jun','Jul','Agos','Set','Out','Nov','Dez'])
margem_lucro_dep_30_final
# Out:
#           0
# Jan   12.12
# Fev   17.59
# Mar  -30.14
# Abr  -22.23
# Mai   -5.21
# Jun   62.74
# Jul   49.99
# Agos  28.28
# Set   22.61
# Out  -10.90
# Nov    4.31
# Dez   52.75

# %%
#Qual foi o lucro após o imposto divido pela receita?

# %%
media_anual = sum(lucro_de_30) / len(lucro_de_30)
media_anual
# Out:
# 1750.6816666666666

# %%
#Considerados Bons Meses (f)

# %%
bons_meses = list([])

for i in range(0, len(lucro)):
  bons_meses.append(lucro_de_30[i] > media_anual)
bons_meses
# Out:
# [True, False, False, False, False, True, True, True, True, False, False, True]

# %%
for i in bons_meses:
  if i == True:
    print('Bom Mês')
  else:
    print('Péssimo Mês')
bom_mes = pd.DataFrame(bons_meses, index=['Jan','Fev', 'Mar','Abr','Mai','Jun','Jul','Agos','Set','Out','Nov','Dez'])
bom_mes
# Out:
# Bom Mês
# Péssimo Mês
# Péssimo Mês
# Péssimo Mês
# Péssimo Mês
# Bom Mês
# Bom Mês
# Bom Mês
# Bom Mês
# Péssimo Mês
# Péssimo Mês
# Bom Mês
#           0
# Jan    True
# Fev   False
# Mar   False
# Abr   False
# Mai   False
# Jun    True
# Jul    True
# Agos   True
# Set    True
# Out   False
# Nov   False
# Dez    True

# %%
#Considerados Meses Críticos (g)

# %%
pessimo_meses = list([])

for i in range(0, len(lucro)):
  pessimo_meses.append(lucro_de_30[i] < media_anual)
pessimo_meses
# Out:
# [False, True, True, True, True, False, False, False, False, True, True, False]

# %%
for i in pessimo_meses:
  if i == True:
    print('Mês Crítico')
  else:
    print('Mês Nao Crítico')
pessimo_mes = pd.DataFrame(pessimo_meses, index=['Jan','Fev', 'Mar','Abr','Mai','Jun','Jul','Agos','Set','Out','Nov','Dez'])
pessimo_mes
# Out:
# Mês Nao Crítico
# Mês Crítico
# Mês Crítico
# Mês Crítico
# Mês Crítico
# Mês Nao Crítico
# Mês Nao Crítico
# Mês Nao Crítico
# Mês Nao Crítico
# Mês Crítico
# Mês Crítico
# Mês Nao Crítico
#    index      0
# 0    Jan  False
# 1    Fev   True
# 2    Mar   True
# 3    Abr   True
# 4    Mai   True
# 5    Jun  False
# 6    Jul  False
# 7   Agos  False
# 8    Set  False
# 9    Out   True
# 10   Nov   True
# 11   Dez  False

# %%
#Qual seria considerado o melhor mês, tendo em conta que o lucro após o imposto foi o máximo para o ano (g)

# %%
melhor_mes = list([])
for i in range(0, len(lucro)):
  melhor_mes.append(lucro_de_30[i] == max(lucro_de_30))
print(melhor_mes, end=' ')
# Out:
# [False, False, False, False, False, False, False, False, False, False, False, True]

# %%
#Qual seria considerado o mau mês, tendo em conta que o lucro após o imposto foi o minimo para o ano

# %%
mau_mes = list([])
for i in range(0, len(lucro)):
  mau_mes.append(lucro_de_30[i] == min(lucro_de_30))
print(mau_mes, end=' ')
# Out:
# [False, False, True, False, False, False, False, False, False, False, False, False]

# %%
#Resumindo:

# %%
print(f"A Empresa Pangui, Lda teve como média anual dos Lucros = {media_anual:.3f} USD ")
# Out:
# A Empresa Pangui, Lda teve como média anual dos Lucros = 1750.682 USD

# %%
print(" O Lucro final depois do imposto de 30% foi de USD:", round(imposto_de_30_final,3))
# Out:
#  O Lucro final depois do imposto de 30% foi de USD:             0
# Jan    756.80
# Fev    573.42
# Mar  -1112.34
# Abr   -874.29
# Mai   -179.98
# Jun   2179.57
# Jul   2463.17
# Agos  1183.49
# Set    998.52
# Out   -671.60
# Nov    197.88
# Dez   3488.86

# %%
print("A Margem de Lucro para cada mês depois do imposto de 30% é de USD:", round(margem_lucro_dep_30_final,3))
# Out:
# A Margem de Lucro para cada mês depois do imposto de 30% é de USD:           0
# Jan   12.12
# Fev   17.59
# Mar  -30.14
# Abr  -22.23
# Mai   -5.21
# Jun   62.74
# Jul   49.99
# Agos  28.28
# Set   22.61
# Out  -10.90
# Nov    4.31
# Dez   52.75
